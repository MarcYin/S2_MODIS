# %%
cd ~/DATA/Sentinel/
# Out:
# /data/store01/data_dirs/students/ucfafyi/Sentinel

# %%
site = 'Zinder'
month = [4,4,4,5,5]
day = [3,13,23,3,13]
lat,lon= 13.77694, 8.99

# %%
for i, j in enumerate(month):
    
    f = open('untitled2.txt', 'r')
    filedata = f.read()
    f.close()
    a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month[i], day[i]))
    b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month[i], day[i]))
    f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month[i], day[i]), 'wb')
    f1.write(b)
    f1.close()

# %%
site = 'Xuzhou'
lat, lon = 34.216944,117.141944
month = 3
day = 21
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'NEOW-OAE'
lat, lon = 35.41083,-99.058889
month = 5
day = 18
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'NEOW-OAE'
lat, lon = 35.41083,-99.058889
month = 6
day = 27
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'NEOW-OAE'
lat, lon = 35.41083,-99.058889
month = 7
day = 17
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Luang'
lat, lon = 20.930833,101.41583
month = 4
day = 12
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Luang'
lat, lon = 20.930833,101.41583
month = 4
day = 25
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'CEILAP'
lat, lon = -38.95194,-68.13694
month = 1
day = 19
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Canberra'
lat, lon = -35.270833,149.11083
month = 1
day = 1
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Bure'
lat, lon = 48.561944,5.505
month = 3
day = 12
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Bure'
lat, lon = 48.561944,5.505
month = 5
day = 8
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'USGS'
lat, lon = 35.215,-111.63389
month = 3
day = 4
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'USGS'
lat, lon = 35.215,-111.63389
month = 3
day = 21
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Munic'
lat, lon = 48.14778,11.572778
month = 1
day = 30
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Munic'
lat, lon = 48.14778,11.572778
month = 2
day = 12
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Munic'
lat, lon = 48.14778,11.572778
month = 4
day = 29
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Amazon'
lat, lon = -2.143889,-59.000
month = 7
day = 17
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Bird'
lat, lon = -25.89889,139.34583
month = 2
day = 5
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
site = 'Bird'
lat, lon = -25.89889,139.34583
month = 4
day = 5
f = open('untitled2.txt', 'r')
filedata = f.read()
f.close()
a = filedata.replace('nothing', '%s,%s,%s,%s,%s'%(site, lat, lon, month, day))
b = a.replace('site, lat, lon, year, month, day =', "site, lat, lon, year, month, day = '%s',%f,%f,%i,%i,%i"%(site, lat, lon,2016, month, day))
f1 = open('%s_%s_%s_%s_%s.py'%(site, lat, lon, month, day), 'wb')
f1.write(b)
f1.close()

# %%
import sys
sys.path.insert(0,'python')
from fastRWpkl import *
from smoothn import *
import pylab as plt
# %matplotlib inline
import mgrs
import pandas as pd
from scipy import interpolate
from nicer_plot import *

# %%
data = parallel_rw_pkl(None, 'Xuzhou0321_atm', 'r')

# %%
aerosols = np.array([[i[0], i[1], i[2][0][0]]for i in data]).T

# %%
aero_map = np.zeros((1000, 1000))
aero_map[:,:] = np.nan
aero_map[(aerosols[0]-1001).astype(int), (aerosols[1]-1001).astype(int)] = aerosols[2]

# %%
weights = (~np.isnan(aero_map)).astype('float')

# %%
sm_aaro = smoothn(aero_map,s=10,W=weights, verbose=True, isrobust=True)
# Out:
# python/smoothn.py:186: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if W != None:
# python/smoothn.py:204: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if W == None:
# tol 1.0 nit 0
# tol 2.34134820731 nit 1
# tol 2.09614218687 nit 2
# tol 1.98893998794 nit 3
# tol 1.44519974488 nit 4
# tol 1.14240118694 nit 5
# tol 0.765162185311 nit 6
# tol 0.547818810349 nit 7
# tol 0.379941193976 nit 8
# tol 0.267132659675 nit 9
# tol 0.196185832168 nit 10
# tol 0.140562704771 nit 11
# tol 0.110756077199 nit 12
# tol 0.0836371254986 nit 13
# tol 0.0713736061961 nit 14
# tol 0.0582187517814 nit 15
# tol 0.0529800290217 nit 16
# tol 0.0463226630721 nit 17
# tol 0.0436132643635 nit 18
# tol 0.0398548736599 nit 19
# tol 0.0380419463157 nit 20
# tol 0.0356219633193 nit 21
# tol 0.0341908270832 nit 22
# tol 0.0324551526947 nit 23
# tol 0.0312474097306 nit 24
# tol 0.0299073906478 nit 25
# ...

# %%
plt.figure(figsize=(10,8))
plt.imshow(sm_aaro[0]*10, interpolation='None')
plt.plot( 307,377, 'r+')
plt.xlim(0,1000)
plt.ylim(1000,0)
plt.axis('off')
plt.colorbar()

# %%
lat, lon = 34.216944,117.141944
tx = mgrs.MGRS()
mg = tx.toMGRS(lat,lon, MGRSPrecision=4)
imgx = 9999-int(mg[-4:]); imgy = int(mg[-8:-4])
imgx,imgy
# Out:
# (1377, 1307)

# %%
pas = ['Date(dd-mm-yyyy)', 'Time(hh:mm:ss)', 'Julian_Day', 'AOT_1640', 
       'AOT_1020', 'AOT_870', 'AOT_675', 'AOT_667', 'AOT_555', 'AOT_551', 'AOT_532', 
       'AOT_531', 'AOT_500', 'AOT_490', 'AOT_443', 'AOT_440', 'AOT_412', 'AOT_380', 'AOT_340', 'Water(cm)']
df = pd.read_csv('160318_160323_XuZhou-CUMT.dubovik', skiprows=3, na_values=["N/A"])
date = df[pas]#[16:23]
aero = np.array(date.AOT_1020),np.array(date.AOT_870),np.array(date.AOT_675),np.array(date.AOT_500),np.array(date.AOT_440),np.array(date.AOT_380),np.array(date.AOT_340)
wv = [ 1020,870, 675, 500, 440, 380, 340]
aero = np.array(aero).T
date
# Out:
#    Date(dd-mm-yyyy) Time(hh:mm:ss)  Julian_Day  AOT_1640  AOT_1020   AOT_870  \
# 0        18:03:2016       02:21:52   78.098519  0.369112  0.736361  0.916329
# 1        18:03:2016       07:21:49   78.306817  0.337082  0.715093  0.921229
# 2        18:03:2016       07:49:49   78.326262  0.365805  0.782380  1.003292
# 3        19:03:2016       00:51:49   79.035984  0.350762  0.751543  0.946709
# 4        19:03:2016       01:21:24   79.056528  0.365943  0.782735  0.986123
# 5        19:03:2016       07:21:25   79.306539  0.163321  0.272548  0.338236
# 6        19:03:2016       07:51:04   79.327130  0.143429  0.232793  0.286936
# 7        19:03:2016       08:45:02   79.364606  0.156080  0.253170  0.306466
# 8        19:03:2016       09:11:35   79.383044  0.179467  0.317241  0.388919
# 9        19:03:2016       23:31:58   79.980532  0.306261  0.463782  0.525868
# 10       19:03:2016       23:56:35   79.997627  0.308796  0.457013  0.513273
# ...

# %%
aero
# Out:
# array([[ 0.118254,  0.143735,  0.195215,  0.297097,  0.35266 ,  0.420007,
#          0.46177 ],
#        [ 0.111815,  0.138148,  0.187186,  0.285862,  0.340215,  0.405996,
#          0.445371],
#        [ 0.125076,  0.159385,  0.218857,  0.336869,  0.401871,  0.475085,
#          0.518014],
#        [ 0.140287,  0.187025,  0.265776,  0.418813,  0.498498,  0.596267,
#          0.65253 ],
#        [ 0.153366,  0.19944 ,  0.283665,  0.444442,  0.52916 ,  0.631912,
#          0.690948],
#        [ 0.18636 ,  0.226377,  0.307671,  0.459384,  0.53817 ,  0.63094 ,
#          0.685863],
#        [ 0.187572,  0.225881,  0.307508,  0.4594  ,  0.538325,  0.631513,
#          0.687064]])

# %%
aot550 = []
plot_config()
#dates = ['01/03', '01/08', '01/13']
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(111)
for i,j in enumerate(aero):
    ax.plot(wv, j)
    f = interpolate.interp1d(wv,j, kind='cubic')
    xnew = 550
    ynew = f(xnew)
    aot550.append(ynew)
    plt.plot(550, ynew, 'r+')
pretty_axes(ax)  
ax.set_yticks(np.linspace(0, 1.2*np.max(aero), 6))
plt.legend(ncol=2)
# Out:
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
aot550
# Out:
# [array(0.2601056749520189),
#  array(0.24985197463696915),
#  array(0.2932833378228902),
#  array(0.3647880284909065),
#  array(0.3873051891073137),
#  array(0.4056003651278786),
#  array(0.405571475920712)]

# %%
mean(aerosols[2])
# Out:
# 0.44927770275882217
