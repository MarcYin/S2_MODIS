# %%
cd ~/DATA/Sentinel/
# Out:
# /data/store01/data_dirs/students/ucfafyi/Sentinel

# %%
import sys
sys.path.insert(0,'python')
from fastRWpkl import *
from smoothn import *
import pylab as plt
# %matplotlib inline
import mgrs
import pandas as pd
from scipy import interpolate
from nicer_plot import *

# %%
data = parallel_rw_pkl(None, 'Amazon0717_atm', 'r')
lat, lon = -2.143889,-59.000000
tx = mgrs.MGRS()
mg = tx.toMGRS(lat,lon, MGRSPrecision=4)
imgx = 9999-int(mg[-4:]); imgy = int(mg[-8:-4])
imgx,imgy
# Out:
# (3710, 7756)

# %%
aerosols = np.array([[i[0], i[1], i[2][0][0]]for i in data]).T
aero_map = np.zeros((1000, 1000))
aero_map[:,:] = np.nan
aero_map[(aerosols[0]-3001).astype(int), (aerosols[1]-7001).astype(int)] = aerosols[2]
weights = (~np.isnan(aero_map)).astype('float')
sm_aaro = smoothn(aero_map,s=10,W=weights, verbose=True, isrobust=True)
# Out:
# python/smoothn.py:186: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if W != None:
# python/smoothn.py:204: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if W == None:
# tol 1.0 nit 0
# tol 2.34117729433 nit 1
# tol 2.09986884887 nit 2
# tol 1.99349185922 nit 3
# tol 1.45238854049 nit 4
# tol 1.14919758628 nit 5
# tol 0.770593804048 nit 6
# tol 0.552240161778 nit 7
# tol 0.383069137398 nit 8
# tol 0.26948923702 nit 9
# tol 0.197694764326 nit 10
# tol 0.141527688312 nit 11
# tol 0.111168995392 nit 12
# tol 0.0836677092417 nit 13
# tol 0.0710840552302 nit 14
# tol 0.0576990086943 nit 15
# tol 0.0523266037423 nit 16
# tol 0.045572364509 nit 17
# tol 0.0428394770793 nit 18
# tol 0.0390669236348 nit 19
# tol 0.0372795910847 nit 20
# tol 0.0348862191673 nit 21
# tol 0.0335002591151 nit 22
# tol 0.0318095890926 nit 23
# tol 0.0306547192543 nit 24
# tol 0.0293674636367 nit 25
# tol 0.0283808168993 nit 26
# tol 0.0273508843644 nit 27
# tol 0.0264993276531 nit 28
# tol 0.0256470235742 nit 29
# tol 0.0249068057595 nit 30
# tol 0.0241841482885 nit 31
# tol 0.0235360323506 nit 32
# tol 0.0229118218543 nit 33
# tol 0.0223399099529 nit 34
# tol 0.0217926752085 nit 35
# tol 0.0212839331673 nit 36
# tol 0.0207982718378 nit 37
# tol 0.0203421222574 nit 38
# tol 0.0199066376249 nit 39
# tol 0.0194945519462 nit 40
# tol 0.0191006067666 nit 41
# tol 0.0187257233958 nit 42
# tol 0.0183666446809 nit 43
# tol 0.018023436182 nit 44
# tol 0.0176939851331 nit 45
# tol 0.0173779818734 nit 46
# tol 0.0170739881568 nit 47
# tol 0.0167815556457 nit 48
# tol 0.0164996580551 nit 49
# tol 0.0162278207468 nit 50
# tol 0.0159652792476 nit 51
# tol 0.0042016174609 nit 35
# tol 0.00415772571433 nit 36
# tol 0.00411638132123 nit 37
# tol 0.00407735650292 nit 38
# tol 0.00404044477125 nit 39
# tol 0.00400545952093 nit 40
# tol 0.0039722317351 nit 41
# tol 0.0039406086767 nit 42
# tol 0.00391045207428 nit 43
# tol 0.0038816369496 nit 44
# tol 0.00385405017716 nit 45
# tol 0.00382758946318 nit 46
# tol 0.00380216219744 nit 47
# tol 0.00377768458266 nit 48
# tol 0.00375408071643 nit 49
# tol 0.00373128186031 nit 50
# tol 0.00370922570405 nit 51
# tol 0.00368785575883 nit 52
# tol 0.00366712076653 nit 53
# tol 0.00364697420027 nit 54
# tol 0.0036273737894 nit 55
# tol 0.00360828111075 nit 56
# tol 0.00358966120629 nit 57
# tol 0.0035714822499 nit 58
# tol 0.00355371523939 nit 59
# tol 0.00353633372546 nit 60
# tol 0.00351931356335 nit 61
# tol 0.00350263269278 nit 62
# tol 0.00348627093745 nit 63
# tol 0.00347020982646 nit 64
# tol 0.00345443243222 nit 65
# tol 0.00343892322554 nit 66
# tol 0.00342366794443 nit 67
# tol 0.00340865347645 nit 68
# tol 0.00339386775229 nit 69
# tol 0.00337929965016 nit 70
# tol 0.00336493890937 nit 71
# tol 0.00335077605249 nit 72
# tol 0.00333680231502 nit 73
# tol 0.00332300958193 nit 74
# tol 0.0033093903303 nit 75
# tol 0.00329593757748 nit 76
# tol 0.0032826448342 nit 77
# tol 0.00326950606213 nit 78
# tol 0.00325651563546 nit 79
# tol 0.00324366830608 nit 80
# tol 0.003230959172 nit 81
# tol 0.00321838364872 nit 82
# tol 0.00320593744322 nit 83
# tol 0.00319361653034 nit 84
# tol 0.00318141713128 nit 85
# tol 0.00316933569407 nit 86
# tol 0.0031573688758 nit 87
# tol 0.00314551352637 nit 88
# tol 0.00313376667373 nit 89
# tol 0.00312212551038 nit 90
# tol 0.00311058738107 nit 91
# tol 0.00309914977151 nit 92
# tol 0.00308781029812 nit 93
# tol 0.00307656669856 nit 94
# tol 0.00306541682311 nit 95
# tol 0.00305435862677 nit 96
# tol 0.00304339016196 nit 97
# tol 0.00303250957191 nit 98
# tol 0.00302171508446 nit 99

# %%
plt.figure(figsize=(10,8))
plt.imshow(sm_aaro[0]*10, interpolation='None')
plt.plot(756,710 ,'r+')
plt.xlim(0,1000)
plt.ylim(1000,0)
plt.axis('off')
plt.colorbar()

# %%
(sm_aaro[0]*10)[710,756]
# Out:
# 0.13352785729468605

# %%
pas = ['Date(dd-mm-yyyy)', 'Time(hh:mm:ss)', 'Julian_Day', 'AOT_1640', 
       'AOT_1020', 'AOT_870', 'AOT_675', 'AOT_667', 'AOT_555', 'AOT_551', 'AOT_532', 
       'AOT_531', 'AOT_500', 'AOT_490', 'AOT_443', 'AOT_440', 'AOT_412', 'AOT_380', 'AOT_340', 'Water(cm)']
df = pd.read_csv('160717_160717_Amazon_ATTO_Tower.dubovik', skiprows=3, na_values=["N/A"])
date = df[pas]
aero = np.array(date.AOT_1020),np.array(date.AOT_870),np.array(date.AOT_675),np.array(date.AOT_500),np.array(date.AOT_440),np.array(date.AOT_380),np.array(date.AOT_340)
wv = [ 1020,870, 675, 500, 440, 380, 340]
aero = np.array(aero).T
date
# Out:
#   Date(dd-mm-yyyy) Time(hh:mm:ss)  Julian_Day  AOT_1640  AOT_1020   AOT_870  \
# 0       17:07:2016       11:09:34  199.464977  0.030444  0.043735  0.052518
# 1       17:07:2016       11:41:01  199.486817  0.031273  0.043945  0.052688
# 2       17:07:2016       12:27:27  199.519062  0.031092  0.042063  0.051877
# 3       17:07:2016       12:54:34  199.537894  0.031492  0.043154  0.052902
# 4       17:07:2016       13:16:42  199.553264  0.031158  0.043011  0.052642
#
#     AOT_675  AOT_667  AOT_555  AOT_551  AOT_532  AOT_531   AOT_500  AOT_490  \
# 0  0.075229      NaN      NaN      NaN      NaN      NaN  0.124934      NaN
# 1  0.076167      NaN      NaN      NaN      NaN      NaN  0.125154      NaN
# 2  0.075487      NaN      NaN      NaN      NaN      NaN  0.121945      NaN
# 3  0.077354      NaN      NaN      NaN      NaN      NaN  0.123899      NaN
# 4  0.077404      NaN      NaN      NaN      NaN      NaN  0.123405      NaN
#
#    AOT_443   AOT_440  AOT_412   AOT_380   AOT_340  Water(cm)
# 0      NaN  0.151208      NaN  0.190000  0.224021   3.560938
# 1      NaN  0.151572      NaN  0.191046  0.228333   3.579518
# 2      NaN  0.147500      NaN  0.187289  0.226607   3.536539
# 3      NaN  0.149909      NaN  0.191139  0.231976   3.547718
# 4      NaN  0.149484      NaN  0.190901  0.232423   3.552655

# %%
aot550 = []
plot_config()
#dates = ['01/03', '01/08', '01/13']
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(111)
for i,j in enumerate(aero):
    ax.plot(wv, j)
    f = interpolate.interp1d(wv,j, kind='cubic')
    xnew = 550
    ynew = f(xnew)
    aot550.append(ynew)
    plt.plot(550, ynew, 'r+')
pretty_axes(ax)  
ax.set_yticks(np.linspace(0, 1.2*np.max(aero), 6))
plt.legend(ncol=2)
# Out:
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/__init__.py:878: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# /home/ucfafyi/.conda/envs/gdal_env/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
aot550
# Out:
# [array(0.10745991536510782),
#  array(0.10774781858381083),
#  array(0.105391930744283),
#  array(0.10727358747449983),
#  array(0.1068641035012072)]
