# %%
import numpy as np
import pylab as plt
# %matplotlib inline

# %%
data = []
for j,i in enumerate(a.split('patch 15\ncosts:')):
    if j>1:
        b = i.split(' ')
        #print  b[4],b
    
        data.append(float(b[4]))

# %%
data = np.array(data)

# %%
ar = np.zeros((20,20))
ar[:] = np.nan

for i,j in enumerate(data):
    ar.ravel()[i] = j

# %%
plt.imshow(ar, interpolation = 'Nearest')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f56dcabedd0>

# %%
data2 = []
for j,i in enumerate(b.split('patch 15\ncosts:')):
    if j>1:
        sp = i.split(' ')
        #print  b[4],b
    
        data2.append(float(sp[4]))

# %%
len(data2) #(slice(-20., -10., 1), slice(-10, 30, 1))
# Out:
# 400

# %%
ar2 = np.zeros((10,40))
ar2[:] = np.nan
for i,j in enumerate(data2):
    ar2.ravel()[i] = j

# %%
plt.imshow(ar2)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f56dcd32710>

# %%
data3 = []
for j,i in enumerate(c.split('patch 15\ncosts:')):
    if j>1:
        sp = i.split(' ')
        #print  b[4],b
    
        data3.append(float(sp[4]))

# %%
ar3 = np.zeros((20,20))
ar3[:] = np.nan
for i,j in enumerate(data3):
    ar3.ravel()[i] = j

# %%
plt.imshow(ar3, vmin = 0.94)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f56dcc05998>

# %%
len(data3) # (slice(-10., 10., 1), slice(10, 30, 1))
# Out:
# 399

# %%
data4 = []
for j,i in enumerate(d.split('patch 15\ncosts:')):
    if j>1:
        sp = i.split(' ')
        #print  b[4],b
    
        data4.append(float(sp[4]))

# %%
ar4 = np.zeros((10,40))
ar4[:] = np.nan
for i,j in enumerate(data4):
    ar4.ravel()[i] = j

# %%
plt.imshow(ar4)

# %%
len(data4) #(slice(10., 20., 1), slice(-10, 30, 1))
# Out:
# 400

# %%
arr = np.zeros((40,40))
arr[:] = np.nan

# %%
arr[:10, :40] = np.array(data2).reshape((10,40))

# %%
for i,j in enumerate(data2[:]):
    arr.ravel()[i] = j

# %%
arr[:10,:] = ar2

# %%
arr[10:30,0:20] = ar

# %%
arr[10:30,20:40] = ar3

# %%
arr[30:,:] = ar4

# %%
plt.imshow(arr, interpolation = 'Nearest')
